# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1)) # collections item containing 50000 most common words and the number of occurences of each
    dictionary = dict()
    for word, _ in count: # count has two values (word and occurences), but the second is assigned to _, which is never used. 
        dictionary[word] = len(dictionary) # i.e. (UNK: 0, the: 1, ...)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index) # i.e. data is list corresponding to words, with their frequency ranking (if in top 5000), or 0 otherwise
    count[0][1] = unk_count # give frequency of UNK (rare words)
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) #reverse dictionary to take index and return word
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5240, 3081, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span) # creates empty deque object, with max_length = span, so it will overwrite first element as more are added if over limit
    for _ in range(span): # fill buffer with first #span numbers in data
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data) # data is huge, so why modulo? Because we can specify data_index and skip window, so it skips back to the beginning
    for i in range(batch_size // num_skips): # floor division
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ] # add target to list
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'a', 'anarchism', 'originated', 'of', 'term', 'originated', 'as']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):
    
    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0)) # assigns random vector to each word (what about duplicates?) For size 128, unlikely
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed, labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.401157
# Nearest to not: decompose, james, conduct, tunneling, limbic, treated, hydrophilic, chlorine,
# Nearest to time: cite, pais, northerners, cape, palos, primary, pittsburgh, bokassa,
# Nearest to its: squared, bulwer, indicated, cymbal, kamenev, standardisation, pyotr, caldwell,
# Nearest to after: malign, broch, flashing, characterizes, escalate, inch, cutaway, polis,
# Nearest to states: biologist, unwittingly, evidently, entrances, digestion, acculturation, bosses, considering,
# Nearest to zero: currencies, hemphill, snell, jacketed, bhaskara, peckinpah, buckets, contraceptive,
# Nearest to a: criminality, satsuma, orie, synopsis, trustee, centers, uniformitarianism, breach,
# Nearest to people: ethylene, cashier, beauregard, presenter, swimmer, priestly, stowe, madge,
# Nearest to when: sunny, try, mina, strips, preached, averages, intimidation, plots,
# Nearest to use: ducktales, monotheism, cog, chording, detained, separatists, popped, boreal,
# Nearest to american: hone, serpent, kvac, erickson, cloudbusting, pilsner, sarris, buson,
# Nearest to so: resonated, lddc, dolmens, genet, masjid, oils, gcl, symphonies,
# Nearest to one: criticized, registering, childe, romanis, courier, mist, hackett, merlin,
# Nearest to all: dmc, stored, taland, montessori, cantonal, infante, alluded, alamos,
# Nearest to but: realistically, montauban, portland, deserves, elektra, fatou, craftsmen, bootstrap,
# Nearest to four: sadism, carthusian, saxe, prehistory, transplant, embarking, utterance, detroit,
# Average loss at step 2000: 4.365585
# Average loss at step 4000: 3.864782
# Average loss at step 6000: 3.783032
# Average loss at step 8000: 3.692170
# Average loss at step 10000: 3.617475
# Nearest to not: it, still, often, also, they, to, usually, be,
# Nearest to time: cite, ripened, ngo, lycopene, descend, knots, caution, primary,
# Nearest to its: his, the, their, indicated, horkheimer, lineman, destry, some,
# Nearest to after: evolves, characterizes, in, curious, malign, predators, polis, broch,
# Nearest to states: acculturation, statistics, settle, digestion, unwittingly, gluons, bosses, protista,
# Nearest to zero: seven, eight, nine, five, six, three, four, two,
# Nearest to a: the, orie, this, any, delineation, supervised, scrape, staff,
# Nearest to people: ethylene, fondation, inflated, charged, spent, aonb, frequency, refitted,
# Nearest to when: sunny, strips, bendis, unrounded, sequel, joint, mani, mina,
# Nearest to use: watergate, plunkett, ducktales, detained, abimelech, matter, bx, grenadines,
# Nearest to american: domine, jethro, hone, sarris, lettres, syndicate, french, vlaanderen,
# Nearest to so: resonated, oils, genet, dolmens, survives, masjid, monterrey, ambivalent,
# Nearest to one: two, three, six, four, eight, five, seven, conjugation,
# Nearest to all: pupil, montessori, rooster, sandhi, pegbox, waltrip, especially, lsd,
# Nearest to but: exceeded, inertia, portland, merely, neologisms, nathan, nemours, and,
# Nearest to four: six, eight, three, seven, five, nine, two, zero,
# Average loss at step 12000: 3.611791
# Average loss at step 14000: 3.572484
# Average loss at step 16000: 3.404124
# Average loss at step 18000: 3.458613
# Average loss at step 20000: 3.536876
# Nearest to not: still, also, usually, they, to, often, chilling, it,
# Nearest to time: caution, loudspeaker, lycopene, trusteeship, assume, samsara, ngo, ripened,
# Nearest to its: their, his, the, some, this, her, unwelcome, bodybuilding,
# Nearest to after: when, levine, evolves, in, before, hegelians, incompetence, marching,
# Nearest to states: digestion, acculturation, bebop, statistics, protista, impairs, mutagens, settle,
# Nearest to zero: five, six, seven, three, four, nine, eight, two,
# Nearest to a: orie, the, any, this, no, very, hoppers, turquoise,
# Nearest to people: countries, others, inflated, charged, terrain, predictive, frequency, allegedly,
# Nearest to when: was, if, sunny, after, where, bendis, apoplexy, were,
# Nearest to use: plunkett, concentration, bx, abimelech, rise, detained, groomed, monotheism,
# Nearest to american: french, domine, serpent, british, relinquish, xenophon, dutch, english,
# Nearest to so: survives, oils, if, encoder, nucleation, resonated, symphonies, often,
# Nearest to one: two, four, three, eight, six, seven, five, nine,
# Nearest to all: many, these, lsd, deconvolution, some, several, manipulates, pupil,
# Nearest to but: however, that, though, which, and, although, was, coursework,
# Nearest to four: three, seven, six, eight, five, two, nine, zero,
# Average loss at step 22000: 3.507618
# Average loss at step 24000: 3.488160
# Average loss at step 26000: 3.479683
# Average loss at step 28000: 3.480312
# Average loss at step 30000: 3.502032
# Nearest to not: still, they, often, it, to, nor, pleading, loaders,
# Nearest to time: loudspeaker, lycopene, trusteeship, caution, assume, period, lively, samsara,
# Nearest to its: their, the, his, ely, her, unwelcome, our, oblong,
# Nearest to after: before, when, until, in, during, michelangelo, by, for,
# Nearest to states: digestion, mutagens, acculturation, protista, impairs, statistics, bebop, kingdom,
# Nearest to zero: five, eight, six, four, three, seven, nine, two,
# Nearest to a: any, the, no, peso, multivibrator, very, orie, useful,
# Nearest to people: countries, others, worrying, inflated, terrain, mankind, aonb, conceptualized,
# Nearest to when: after, if, where, before, during, however, while, was,
# Nearest to use: concentration, medica, watergate, practice, rise, characteristics, grenadines, murder,
# Nearest to american: british, english, french, canadian, italian, dutch, seizing, scottish,
# Nearest to so: encoder, often, if, survives, think, nucleation, circumcision, oils,
# Nearest to one: two, seven, four, eight, three, nine, six, five,
# Nearest to all: these, many, several, some, any, vre, cucurbitaceae, manipulates,
# Nearest to but: however, although, and, though, see, which, while, he,
# Nearest to four: five, three, six, eight, seven, two, nine, zero,
# Average loss at step 32000: 3.500849
# Average loss at step 34000: 3.493260
# Average loss at step 36000: 3.455803
# Average loss at step 38000: 3.302424
# Average loss at step 40000: 3.427544
# Nearest to not: still, they, never, it, usually, chilling, often, loaders,
# Nearest to time: year, period, assume, materialized, caution, trusteeship, dioxide, loudspeaker,
# Nearest to its: their, his, her, the, our, ely, lascaris, plagioclase,
# Nearest to after: before, when, during, saws, despite, cephalon, from, until,
# Nearest to states: kingdom, impairs, mutagens, influences, protista, bebop, statistics, countries,
# Nearest to zero: seven, five, eight, nine, four, six, three, two,
# Nearest to a: any, peso, the, orie, another, no, wasps, lollard,
# Nearest to people: those, others, honeywell, frequency, worrying, cities, selves, aonb,
# Nearest to when: if, where, after, before, while, until, during, did,
# Nearest to use: concentration, rise, practice, medica, characteristics, evidences, producers, hb,
# Nearest to american: british, french, dutch, italian, english, rashi, australian, scottish,
# Nearest to so: think, encoder, survives, monterrey, luminaries, nucleation, deceit, oils,
# Nearest to one: seven, four, eight, two, six, five, nine, three,
# Nearest to all: these, any, every, each, cucurbitaceae, many, several, vre,
# Nearest to but: however, although, and, though, while, it, which, almost,
# Nearest to four: six, seven, three, five, eight, two, nine, one,
# Average loss at step 42000: 3.437601
# Average loss at step 44000: 3.455512
# Average loss at step 46000: 3.452138
# Average loss at step 48000: 3.356058
# Average loss at step 50000: 3.383946
# Nearest to not: still, usually, generally, they, sor, never, occasionally, polysaccharides,
# Nearest to time: year, period, assume, point, day, bandanese, geocities, lycopene,
# Nearest to its: their, his, the, her, our, wladislaus, your, tesco,
# Nearest to after: before, when, during, despite, until, from, while, cephalon,
# Nearest to states: kingdom, tirthankaras, impairs, mutagens, protista, digestion, nations, mousetrap,
# Nearest to zero: five, seven, eight, six, four, nine, three, two,
# Nearest to a: any, another, the, orie, no, depicted, peso, pose,
# Nearest to people: those, worrying, honeywell, conceptualized, mankind, fung, inflated, selves,
# Nearest to when: while, if, after, where, before, during, however, until,
# Nearest to use: rise, concentration, characteristics, practice, medica, murder, syllogisms, evidences,
# Nearest to american: british, french, english, dutch, scottish, italian, australian, discards,
# Nearest to so: if, survives, encoder, think, nucleation, then, when, amritsar,
# Nearest to one: two, six, seven, eight, four, three, five, nine,
# Nearest to all: both, these, each, saxony, every, any, many, hellene,
# Nearest to but: however, although, though, and, than, while, when, reduces,
# Nearest to four: six, five, three, eight, seven, nine, two, zero,
# Average loss at step 52000: 3.437592
# Average loss at step 54000: 3.429585
# Average loss at step 56000: 3.436956
# Average loss at step 58000: 3.398177
# Average loss at step 60000: 3.396430
# Nearest to not: still, now, they, usually, never, occasionally, to, gildas,
# Nearest to time: period, year, assume, celebrations, automation, samsara, bandanese, summa,
# Nearest to its: their, his, her, the, our, tesco, your, ely,
# Nearest to after: before, during, when, despite, until, without, although, from,
# Nearest to states: kingdom, nations, countries, impairs, mutagens, governments, mousetrap, influences,
# Nearest to zero: five, four, eight, seven, six, nine, three, two,
# Nearest to a: another, the, any, every, orie, no, depicted, peso,
# Nearest to people: those, others, players, worrying, individuals, honeywell, mankind, conceptualized,
# Nearest to when: if, while, before, where, although, after, during, however,
# Nearest to use: practice, rise, characteristics, concentration, most, murder, hb, mainz,
# Nearest to american: british, australian, scottish, dutch, french, english, discards, international,
# Nearest to so: if, survives, ironic, enough, think, normally, expositions, when,
# Nearest to one: two, six, seven, four, eight, three, five, nine,
# Nearest to all: both, every, any, these, some, many, those, each,
# Nearest to but: however, and, although, though, than, see, are, reduces,
# Nearest to four: five, three, eight, six, seven, nine, two, zero,
# Average loss at step 62000: 3.243298
# Average loss at step 64000: 3.254493
# Average loss at step 66000: 3.404904
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-3446420b5935> in <module>()
#       7   for step in range(num_steps):
#       8     batch_data, batch_labels = generate_batch(
# ----> 9       batch_size, num_skips, skip_window)
#      10     feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
#      11     _, l = session.run([optimizer, loss], feed_dict=feed_dict)
#
# <ipython-input-15-6c9c2ecc4e44> in generate_batch(batch_size, num_skips, skip_window)
#      17         for j in range(num_skips):
#      18             while target in targets_to_avoid:
# ---> 19                 target = random.randint(0, span - 1)
#      20             targets_to_avoid.append(target)
#      21             batch[i * num_skips + j] = buffer[skip_window]
#
# /Users/JAustin/anaconda/envs/tensorflow/lib/python3.5/random.py in randint(self, a, b)
#     225         """
#     226
# --> 227         return self.randrange(a, b+1)
#     228
#     229     def _randbelow(self, n, int=int, maxsize=1<<BPF, type=type,
#
# /Users/JAustin/anaconda/envs/tensorflow/lib/python3.5/random.py in randrange(self, start, stop, step, _int)
#     201         width = istop - istart
#     202         if step == 1 and width > 0:
# --> 203             return istart + self._randbelow(width)
#     204         if step == 1:
#     205             raise ValueError("empty range for randrange() (%d,%d, %d)" % (istart, istop, width))
#
# KeyboardInterrupt:
